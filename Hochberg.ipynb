# %% [markdown]
# #  Replicating Hochberg book

# %%
import numpy as np
from matplotlib import pyplot as plt

import tidy3d as td
from generate_mesh import gen_mesh

import devsim as ds

# %%
# all units in um
w_core = 0.25
h_core = 0.22
#w_clearance = 0.5
w_clearance = 2.25
h_clearance = 0.09
w_side = 2.5
h_side = 0.22

w_contact = 1.2
h_contact = 0.2

z_size = h_clearance/5

res = h_clearance/10

#z_size = h_clearance/2

# modulator doping concentrations (1/cm^3)
conc_p = 7e17 + 1e15
conc_n = 5e17

conc_contact = 5e18

# %%
# get 2D doping distributions and visualize
import doping_hochberg as doping
acceptors_dist, donors_dist = doping.get_dopings_hochberg()
(acceptors_dist-donors_dist).plot(y="y")

# %%
eps_Si = 11.7

Si = td.Medium(
    electric_spec=td.SemiConductorSpec(
        conductivity=1,
        permittivity=4,
        donors=0,
        acceptors=0,
    ),
    name="Si",
)

Si_p = td.Medium(
    electric_spec=td.SemiConductorSpec(
        conductivity=1,
        permittivity=eps_Si,
        donors=0,
        acceptors=conc_p,
    ),
    name="Si_p",
)

Si_ppp = td.Medium(
    electric_spec=td.SemiConductorSpec(
        conductivity=1,
        permittivity=eps_Si,
        donors=0,
        acceptors=conc_contact,
    ),
    name="Si_ppp",
)

Si_n = td.Medium(
    electric_spec=td.SemiConductorSpec(
        conductivity=1,
        permittivity=eps_Si,
        donors=conc_n,
        acceptors=1e15,
    ),
    name="Si_n",
)

Si_nnn = td.Medium(
    electric_spec=td.SemiConductorSpec(
        conductivity=1,
        permittivity=eps_Si,
        donors=conc_contact,
        acceptors=1e15,
    ),
    name="Si_nnn",
)

Si_2D_doping = td.Medium(
    electric_spec=td.SemiConductorSpec(
        conductivity=1,
        permittivity=eps_Si,
        donors=0,
        acceptors=acceptors_dist-donors_dist,
    ),
    name="Si_nnn",
)

aux_left = td.Medium(
    heat_spec=td.FluidSpec(),
    name="aux_left"
)

aux_right = td.Medium(
    heat_spec=td.FluidSpec(),
    name="aux_right"
)

air = td.Medium(heat_spec=td.FluidSpec(), name="air")

# %%
# create objects
overlap_factor = 1.0001

oxide = td.Structure(
    geometry=td.Box(center=(0, h_core, 0), size=(5, 2*h_core, z_size)),
    medium=Si,
    name="oxide"
)

core_p = td.Structure(
    geometry=td.Box(center=(-w_core/2, h_core/2, 0), size=(w_core, h_core, z_size)),
    medium=Si_2D_doping,
    name="core_p"
)

core_n = td.Structure(
    geometry=td.Box(center=(w_core/2, h_core/2, 0), size=(w_core, h_core, z_size)),
    medium=Si_2D_doping,
    name="core_n"
)

clearance_p = td.Structure(
    geometry=td.Box(center=(-w_core - w_clearance/2, h_clearance/2, 0), size=(w_clearance, h_clearance, z_size)),
    medium=Si_2D_doping,
    name="clearance_p"
)

clearance_n = td.Structure(
    geometry=td.Box(center=(w_core + w_clearance/2, h_clearance/2, 0), size=(w_clearance, h_clearance, z_size)),
    medium=Si_2D_doping,
    name="clearance_n"
)

side_p = td.Structure(
    geometry=td.Box(center=(-w_core - w_clearance - w_side/2, h_side/2, 0), size=(w_side, h_side, z_size)),
    medium=Si_2D_doping,
    name="side_p"
)

side_n = td.Structure(
    geometry=td.Box(center=(w_core + w_clearance + w_side/2, h_side/2, 0), size=(w_side, h_side, z_size)),
    medium=Si_2D_doping,
    name="side_n"
)

# create a couple structs to define the contacts
contact_left = td.Structure(
    geometry=td.Box(center=(-w_core - w_clearance - w_side + w_contact/2, h_side + h_contact/2, 0), size=(w_contact, h_contact, z_size)),
    medium=aux_left,
    name="contact_left"
)

contact_right = td.Structure(
    geometry=td.Box(center=(w_core + w_clearance + w_side - w_contact/2, h_side + h_contact/2, 0), size=(w_contact, h_contact, z_size)),
    medium=aux_right,
    name="contact_right"
)

# %%
# create a scene with the previous structures
all_structures = [core_p, core_n, clearance_n, clearance_p, side_p, side_n, contact_left, contact_right]

scene = td.Scene(
    medium=air,
    structures=all_structures,
)


_, ax = plt.subplots(2, 1, figsize=(10, 5))

scene.plot(z=0, ax=ax[0])
scene.plot(y=5e-6, ax=ax[1])
plt.show()

# %%
# create BCs
voltages = list(np.linspace(-0.5, 4, 20))
#voltages = [0, 0.1, 0.2]
bc_v1 = td.HeatChargeBoundarySpec(
    condition=td.VoltageBC(voltage=0),
    placement=td.MediumMediumInterface(mediums=[aux_left.name, Si_2D_doping.name]),
)

bc_v2 = td.HeatChargeBoundarySpec(
    #condition=td.VoltageBC(voltage=0),
    condition=td.VoltageBC(voltage=voltages),
    placement=td.MediumMediumInterface(mediums=[aux_right.name, Si_2D_doping.name]),
)

boundary_conditions = [bc_v1, bc_v2]

# %%
# monitors
charge_3D_mnt = td.ChargeSimulationMonitor(
    center=(0, 0.14, 0), size=(0.6, 0.3, td.inf), name="charge_3D_mnt", unstructured=True
)

charge_monitor_z0 = td.ChargeSimulationMonitor(
    center=(0, 0.14, 0), size=(0.6, 0.3, 0), name="charge_z0", unstructured=True, 
)

# %%
# devsim setting 
from tidy3d import DevsimConvergenceSettings
convergence_settings = DevsimConvergenceSettings(relTol=1e5, absTol=1e3, maxIters=400, dV=0.3)
#convergence_settings = DevsimConvergenceSettings(relTol=1e15, absTol=1e15, maxIters=400, dV=0.3)

# %%
# mesh
mesh = td.UniformUnstructuredGrid(dl=res, relative_min_dl=0)
mesh = td.DistanceUnstructuredGrid(dl_interface=res*0.7, dl_bulk=res*2, distance_interface=res*3,
                                  distance_bulk=res*5, relative_min_dl=0)
mesh = td.DistanceUnstructuredGrid(dl_interface=res*0.75, dl_bulk=res*1.95, distance_interface=2*h_side,
                                  distance_bulk=2*h_side, relative_min_dl=0,
                                  #non_refined_structures=[clearance_n.name, clearance_p.name, side_p.name, side_n.name]
                                   non_refined_structures=[oxide.name, clearance_n.name, clearance_p.name, side_p.name, side_n.name]
                                  )

# build heat simulation object
heat_sim = td.HeatChargeSimulation(
    sources=[],
    monitors=[charge_3D_mnt, charge_monitor_z0],
    devsim_settings=[convergence_settings],
    center=(0,0,0),
    size=(10.5,5,5),
    structures=all_structures,
    medium=air,
    boundary_spec=boundary_conditions,
    grid_spec=mesh,
    #grid_spec=td.UniformUnstructuredGrid(dl=res, relative_min_dl=3e-7),
    symmetry=(0, 0, 0)
    )
heat_sim.plot(z=0)
# Out:
# 17:21:01 CEST WARNING: Structure 'oxide' listed as a non-refined structure in
#               'HeatChargeSimulation.grid_spec' is not present in
#               'HeatChargeSimulation.structures'
# <Axes: title={'center': 'cross section at z=0.00 (μm)'}, xlabel='x (μm)', ylabel='y (μm)'>

# %% [markdown]
# ### Run pipeline

# %%
# %matplotlib inline
#heat_sim_data = gen_mesh(heat_sim)
from run_drift import run_drift
devsim_data = run_drift(heat_sim)
# Out:
# [24-10-17 17:21:03.293][DEBUG  ]: Remote run: False
# [24-10-17 17:21:03.293][DEBUG  ]: Listing client arguments:
# [24-10-17 17:21:03.293][DEBUG  ]:    checkEstimateUri:
# [24-10-17 17:21:03.293][DEBUG  ]:    estWorkUnitFile: ./tmp/est_work_unit.json
# [24-10-17 17:21:03.293][DEBUG  ]:    ignoreError: false
# [24-10-17 17:21:03.293][DEBUG  ]:    validateOnly: false
# [24-10-17 17:21:03.293][DEBUG  ]:    resourceId: tmp
# [24-10-17 17:21:03.293][DEBUG  ]:    releasePath: /home/marc/Documents/src/tidy3d-core/_build_release
# [24-10-17 17:21:03.293][DEBUG  ]:    fileSystem: distributed
# [24-10-17 17:21:03.293][SUPPORT]: Starting tidy3dHeatMetaDataPipeline for task id tmp
# [24-10-17 17:21:03.293][SUPPORT]: Using 'simulation.hdf5' file found in folder.
# [24-10-17 17:21:03.293][DEBUG  ]: Starting heavy imports
# [24-10-17 17:21:03.294][DEBUG  ]: Done with heavy imports
# [24-10-17 17:21:03.379][USER   ]: WARNING: Structure 'oxide' listed as a non-refined structure in
# 'HeatChargeSimulation.grid_spec' is not present in 'HeatChargeSimulation.structures'
# [24-10-17 17:21:03.413][DEBUG  ]: Listing metadata client updates
# [24-10-17 17:21:03.414][DEBUG  ]:    estFlexUnit: 0.025
# [24-10-17 17:21:03.414][DEBUG  ]:    metadataStatus: success
# [24-10-17 17:21:03.415][DEBUG  ]:    md5: 5cab86ca2afa5ac6cd90c56f5ebd569e
# [24-10-17 17:21:03.415][SUPPORT]: Running uploadFiles : /bin/true
# [24-10-17 17:21:03.415][SUPPORT]: **********   Begin content of uploadFiles.log **********
# [24-10-17 17:21:03.416][SUPPORT]: **********   End content of uploadFiles.log **********
# [24-10-17 17:21:03.416][SUPPORT]: Finishing uploadFiles: execution time is 0.00 seconds
# [24-10-17 17:21:03.416][SUPPORT]: Processing Tidy3D Heat Solver, pipeline tidy3dHeatMetaDataPipeline complete.
# [24-10-17 17:21:05.189][DEBUG  ]: Remote run: False
# [24-10-17 17:21:05.189][DEBUG  ]: Listing client arguments:
# [24-10-17 17:21:05.189][DEBUG  ]:    workUnitFile: ./tmp/work_unit.json
# [24-10-17 17:21:05.189][DEBUG  ]:    name:
# [24-10-17 17:21:05.189][DEBUG  ]:    numProcessors: 1
# [24-10-17 17:21:05.189][DEBUG  ]:    releasePath: /home/marc/Documents/src/tidy3d-core/_build_release
# [24-10-17 17:21:05.189][DEBUG  ]:    numNodes: 1
# [24-10-17 17:21:05.189][DEBUG  ]:    taskFile: ./simulation.hdf5
# [24-10-17 17:21:05.189][DEBUG  ]:    denormalize: true
# [24-10-17 17:21:05.189][DEBUG  ]:    threadsPerProcess: 1
# [24-10-17 17:21:05.189][DEBUG  ]:    resourceId: tmp
# [24-10-17 17:21:05.189][DEBUG  ]:    fileSystem: distributed
# [24-10-17 17:21:05.189][SUPPORT]: Starting tidy3dHeatSolverPipeline for task id tmp
# [24-10-17 17:21:05.189][SUPPORT]: Downloading files: ['./output/tidy3d_metadata.json']
# [24-10-17 17:21:05.189][SUPPORT]: Running downloadAuxFiles : /bin/true
# [24-10-17 17:21:05.189][SUPPORT]: Running meshHeatSimulation : /home/marc/Documents/src/tidy3d-core/_build_release/bin/flow360runner.py /home/marc/Documents/src/tidy3d-core/_build_release/bin/mesh_heat_simulation.py --sim_file ./simulation.hdf5 --mesh_file ./tmp/mesh.msh --cgns_file ./mesh.cgns --heat_charge_conf_json {'cases': './current_sim.pckl', 'heat_sim_config': './HEAT_case_config.json', 'heat_mesh_casefile': './HEAT_mesh_config.json', 'heat_vtu_file': './HEAT_proc0.vtu', 'conduction_sim_config': './CONDUCTION_case_config.json', 'conduction_mesh_casefile': './CONDUCTION_mesh_config.json', 'conduction_vtu_file': './CONDUCTION_proc0.vtu', 'heat_time_series_base': './volume_time_', 'devsim_config': './DEVSIM_config.json', 'devsim_vtu_file': 'devsim_3D.vtu', 'devsim_bias_series_base': 'devsim_bias_', 'devsim_IV_file': 'devsim_IV.pckl', 'doping_SpatialDataArray': 'doping_SpatialDataArrays.pckl'} --sim_pickle ./tmp/heat_simulation.pckl --num_threads 1
# [24-10-17 17:21:05.190][SUPPORT]: **********   Begin content of meshHeatSimulation.log **********
# zone_1
# zone_2
# zone_3
# zone_4
# zone_5
# zone_6
# [24-10-17 17:21:07.776][SUPPORT]: **********   End content of meshHeatSimulation.log **********
# [24-10-17 17:21:07.776][SUPPORT]: Finishing meshHeatSimulation: execution time is 2.59 seconds
# Resetting DEVSIM
# Physical group name bc_0 has 0 Tetrahedra.
# Physical group name bc_0 has 98 Triangles.
# Physical group name bc_0 has 164 Lines.
# Physical group name bc_0 has 67 Points.
# Physical group name bc_1 has 0 Tetrahedra.
# Physical group name bc_1 has 232 Triangles.
# Physical group name bc_1 has 384 Lines.
# Physical group name bc_1 has 153 Points.
# Physical group name bc_2 has 0 Tetrahedra.
# Physical group name bc_2 has 102 Triangles.
# Physical group name bc_2 has 170 Lines.
# Physical group name bc_2 has 69 Points.
# Physical group name bc_3 has 0 Tetrahedra.
# Physical group name bc_3 has 22 Triangles.
# Physical group name bc_3 has 41 Lines.
# Physical group name bc_3 has 20 Points.
# Physical group name bc_4 has 0 Tetrahedra.
# Physical group name bc_4 has 22 Triangles.
# Physical group name bc_4 has 41 Lines.
# Physical group name bc_4 has 20 Points.
# Physical group name bc_5 has 0 Tetrahedra.
# Physical group name bc_5 has 274 Triangles.
# Physical group name bc_5 has 482 Lines.
# Physical group name bc_5 has 209 Points.
# Physical group name bc_6 has 0 Tetrahedra.
# Physical group name bc_6 has 274 Triangles.
# Physical group name bc_6 has 482 Lines.
# Physical group name bc_6 has 209 Points.
# Physical group name zone_1 has 16312 Tetrahedra.
# Physical group name zone_1 has 36307 Triangles.
# Physical group name zone_1 has 24574 Lines.
# Physical group name zone_1 has 4580 Points.
# Physical group name zone_2 has 16410 Tetrahedra.
# Physical group name zone_2 has 36505 Triangles.
# Physical group name zone_2 has 24695 Lines.
# Physical group name zone_2 has 4601 Points.
# Physical group name zone_3 has 10785 Tetrahedra.
# Physical group name zone_3 has 24914 Triangles.
# Physical group name zone_3 has 17744 Lines.
# Physical group name zone_3 has 3616 Points.
# Physical group name zone_4 has 10833 Tetrahedra.
# Physical group name zone_4 has 25019 Triangles.
# Physical group name zone_4 has 17808 Lines.
# Physical group name zone_4 has 3623 Points.
# Physical group name zone_5 has 15512 Tetrahedra.
# Physical group name zone_5 has 36477 Triangles.
# Physical group name zone_5 has 26419 Lines.
# Physical group name zone_5 has 5455 Points.
# Physical group name zone_6 has 15565 Tetrahedra.
# Physical group name zone_6 has 36595 Triangles.
# Physical group name zone_6 has 26496 Lines.
# Physical group name zone_6 has 5467 Points.
# Device device has 27013 coordinates with max index 27013
# Region zone_1 has 4580 nodes.
# Region zone_2 has 4601 nodes.
# Region zone_3 has 3616 nodes.
# Region zone_4 has 3623 nodes.
# Region zone_5 has 5455 nodes.
# Region zone_6 has 5467 nodes.
# Contact zone_5_bc_5 in region zone_5 with 209 nodes
# Contact zone_6_bc_6 in region zone_6 with 209 nodes
# Adding interface zone_1_bc_0 with 67, 67 nodes
# Adding interface zone_1_bc_1 with 153, 153 nodes
# Adding interface zone_2_bc_2 with 69, 69 nodes
# Adding interface zone_3_bc_3 with 20, 20 nodes
# Adding interface zone_4_bc_4 with 20, 20 nodes
# Interpolating Acceptors in region zone_1
# Interpolating Acceptors in region zone_2
# Interpolating Acceptors in region zone_3
# Interpolating Acceptors in region zone_4
# Interpolating Acceptors in region zone_5
# Interpolating Acceptors in region zone_6
# Warning: Replacing equation with equation of the same name.
# Region: zone_1, Equation: PotentialEquation, Variable: Potential
# Warning: Replacing equation with equation of the same name.
# Region: zone_2, Equation: PotentialEquation, Variable: Potential
# Warning: Replacing equation with equation of the same name.
# Region: zone_3, Equation: PotentialEquation, Variable: Potential
# Warning: Replacing equation with equation of the same name.
# Region: zone_4, Equation: PotentialEquation, Variable: Potential
# Warning: Replacing equation with equation of the same name.
# Region: zone_5, Equation: PotentialEquation, Variable: Potential
# Warning: Replacing equation with equation of the same name.
# Region: zone_6, Equation: PotentialEquation, Variable: Potential
# number of equations 82026
# Iteration: 0
#   Device: "device"	RelError: 2.00000e+08	AbsError: 1.37386e+18
#     Region: "zone_1"	RelError: 3.00000e+00	AbsError: 1.02463e+18
#       Equation: "ElectronContinuityEquation"	RelError: 1.00000e+00	AbsError: 4.98366e+17
#       Equation: "HoleContinuityEquation"	RelError: 1.00000e+00	AbsError: 5.26268e+17
#       Equation: "PotentialEquation"	RelError: 1.00000e+00	AbsError: 2.62873e-01
#     Region: "zone_2"	RelError: 3.00000e+00	AbsError: 1.02462e+18
#       Equation: "ElectronContinuityEquation"	RelError: 1.00000e+00	AbsError: 5.23333e+17
#       Equation: "HoleContinuityEquation"	RelError: 1.00000e+00	AbsError: 5.01290e+17
#       Equation: "PotentialEquation"	RelError: 1.00000e+00	AbsError: 2.57272e-01
#     Region: "zone_3"	RelError: 3.00000e+00	AbsError: 1.37349e+18
#       Equation: "ElectronContinuityEquation"	RelError: 1.00000e+00	AbsError: 8.93516e+17
#       Equation: "HoleContinuityEquation"	RelError: 1.00000e+00	AbsError: 4.79970e+17
#       Equation: "PotentialEquation"	RelError: 1.00000e+00	AbsError: 2.57283e-01
#     Region: "zone_4"	RelError: 3.00000e+00	AbsError: 1.37386e+18
#       Equation: "ElectronContinuityEquation"	RelError: 1.00000e+00	AbsError: 4.76763e+17
#       Equation: "HoleContinuityEquation"	RelError: 1.00000e+00	AbsError: 8.97102e+17
#       Equation: "PotentialEquation"	RelError: 1.00000e+00	AbsError: 2.77024e-01
#     Region: "zone_5"	RelError: 1.00100e+08	AbsError: 1.10804e+18
#       Equation: "ElectronContinuityEquation"	RelError: 1.00100e+08	AbsError: 1.07034e+17
#       Equation: "HoleContinuityEquation"	RelError: 1.00000e+00	AbsError: 1.00100e+18
#       Equation: "PotentialEquation"	RelError: 1.00000e+00	AbsError: 2.73963e-01
#     Region: "zone_6"	RelError: 9.99000e+07	AbsError: 1.10809e+18
#       Equation: "ElectronContinuityEquation"	RelError: 1.00000e+00	AbsError: 9.99000e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+07	AbsError: 1.09089e+17
#       Equation: "PotentialEquation"	RelError: 1.00000e+00	AbsError: 2.57283e-01
# Iteration: 1
#   Device: "device"	RelError: 4.03354e+04	AbsError: 1.29911e+18
#     Region: "zone_1"	RelError: 1.99809e+03	AbsError: 1.02361e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 4.97868e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.25742e+17
#       Equation: "PotentialEquation"	RelError: 9.23100e-02	AbsError: 2.67334e-02
#     Region: "zone_2"	RelError: 1.99811e+03	AbsError: 1.02360e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.22810e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.00789e+17
#       Equation: "PotentialEquation"	RelError: 1.14235e-01	AbsError: 2.58700e-02
#     Region: "zone_3"	RelError: 2.00063e+03	AbsError: 1.11736e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 6.37865e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 4.79490e+17
#       Equation: "PotentialEquation"	RelError: 2.62941e+00	AbsError: 6.93649e-02
#     Region: "zone_4"	RelError: 2.50860e+03	AbsError: 1.29911e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 4.76286e+17
#       Equation: "HoleContinuityEquation"	RelError: 1.50944e+03	AbsError: 8.22826e+17
#       Equation: "PotentialEquation"	RelError: 1.67676e-01	AbsError: 5.51603e-02
#     Region: "zone_5"	RelError: 9.99897e+02	AbsError: 8.07759e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.06927e+17
#       Equation: "HoleContinuityEquation"	RelError: 4.11811e-01	AbsError: 7.00831e+17
#       Equation: "PotentialEquation"	RelError: 4.85603e-01	AbsError: 7.24858e-02
#     Region: "zone_6"	RelError: 3.08300e+04	AbsError: 7.06946e+17
#       Equation: "ElectronContinuityEquation"	RelError: 4.01890e-01	AbsError: 5.97967e+17
#       Equation: "HoleContinuityEquation"	RelError: 3.08291e+04	AbsError: 1.08980e+17
#       Equation: "PotentialEquation"	RelError: 4.85601e-01	AbsError: 7.24828e-02
# Iteration: 2
#   Device: "device"	RelError: 1.14765e+04	AbsError: 4.76187e+18
#     Region: "zone_1"	RelError: 1.99951e+03	AbsError: 1.97217e+16
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 4.97868e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.92239e+16
#       Equation: "PotentialEquation"	RelError: 1.51432e+00	AbsError: 1.56226e-01
#     Region: "zone_2"	RelError: 2.00176e+03	AbsError: 1.02360e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.22810e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.00789e+14
#       Equation: "PotentialEquation"	RelError: 3.76344e+00	AbsError: 1.77700e-01
#     Region: "zone_3"	RelError: 5.47382e+03	AbsError: 4.76187e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 3.64052e+18
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.12135e+18
#       Equation: "PotentialEquation"	RelError: 3.47582e+03	AbsError: 1.83223e-01
#     Region: "zone_4"	RelError: 1.99835e+03	AbsError: 7.47806e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.20883e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 7.35718e+17
#       Equation: "PotentialEquation"	RelError: 3.49687e-01	AbsError: 1.62021e-01
#     Region: "zone_5"	RelError: 1.63505e+00	AbsError: 4.30089e+17
#       Equation: "ElectronContinuityEquation"	RelError: 1.00000e+00	AbsError: 3.94531e+15
#       Equation: "HoleContinuityEquation"	RelError: 3.23194e-01	AbsError: 4.26143e+17
#       Equation: "PotentialEquation"	RelError: 3.11857e-01	AbsError: 6.76469e-02
#     Region: "zone_6"	RelError: 1.37719e+00	AbsError: 1.93337e+17
#       Equation: "ElectronContinuityEquation"	RelError: 6.54326e-02	AbsError: 1.02586e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99902e-01	AbsError: 9.07511e+16
#       Equation: "PotentialEquation"	RelError: 3.11854e-01	AbsError: 6.76436e-02
# Iteration: 3
#   Device: "device"	RelError: 2.75028e+04	AbsError: 4.56499e+18
#     Region: "zone_1"	RelError: 1.00054e+03	AbsError: 1.12849e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99985e-01	AbsError: 3.36635e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.09483e+18
#       Equation: "PotentialEquation"	RelError: 5.35808e-01	AbsError: 1.35219e-01
#     Region: "zone_2"	RelError: 1.47811e+04	AbsError: 2.93169e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99998e-01	AbsError: 2.93168e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.00789e+11
#       Equation: "PotentialEquation"	RelError: 1.37811e+04	AbsError: 1.20393e-01
#     Region: "zone_3"	RelError: 2.00312e+03	AbsError: 4.56499e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 3.66460e+18
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 9.00393e+17
#       Equation: "PotentialEquation"	RelError: 5.11624e+00	AbsError: 7.85348e-02
#     Region: "zone_4"	RelError: 1.00064e+03	AbsError: 1.22066e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.21647e+16
#       Equation: "HoleContinuityEquation"	RelError: 1.43189e+00	AbsError: 1.20849e+18
#       Equation: "PotentialEquation"	RelError: 2.04881e-01	AbsError: 1.06612e-01
#     Region: "zone_5"	RelError: 8.71682e+03	AbsError: 1.72410e+16
#       Equation: "ElectronContinuityEquation"	RelError: 8.71658e+03	AbsError: 3.94477e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.25201e-02	AbsError: 1.32963e+16
#       Equation: "PotentialEquation"	RelError: 2.22664e-01	AbsError: 6.21347e-02
#     Region: "zone_6"	RelError: 5.28893e-01	AbsError: 4.33750e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.94963e-02	AbsError: 2.16665e+16
#       Equation: "HoleContinuityEquation"	RelError: 2.86737e-01	AbsError: 2.17085e+16
#       Equation: "PotentialEquation"	RelError: 2.22660e-01	AbsError: 6.21308e-02
# Iteration: 4
#   Device: "device"	RelError: 3.54060e+04	AbsError: 9.61475e+17
#     Region: "zone_1"	RelError: 1.99862e+03	AbsError: 6.93591e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 3.36303e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 6.59961e+17
#       Equation: "PotentialEquation"	RelError: 6.16883e-01	AbsError: 8.45072e-02
#     Region: "zone_2"	RelError: 2.02512e+04	AbsError: 9.61475e+17
#       Equation: "ElectronContinuityEquation"	RelError: 8.64192e+03	AbsError: 9.61475e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.00789e+08
#       Equation: "PotentialEquation"	RelError: 1.06103e+04	AbsError: 8.94374e-02
#     Region: "zone_3"	RelError: 1.00085e+03	AbsError: 5.25874e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.86104e-01	AbsError: 4.11944e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.13930e+17
#       Equation: "PotentialEquation"	RelError: 8.62951e-01	AbsError: 7.27787e-02
#     Region: "zone_4"	RelError: 1.00093e+03	AbsError: 7.21396e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 9.73046e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.83888e+00	AbsError: 7.11665e+17
#       Equation: "PotentialEquation"	RelError: 8.96625e-02	AbsError: 3.60748e-02
#     Region: "zone_5"	RelError: 1.11538e+04	AbsError: 2.91859e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.11537e+04	AbsError: 1.09207e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.82557e-03	AbsError: 1.82652e+15
#       Equation: "PotentialEquation"	RelError: 1.66569e-01	AbsError: 5.57709e-02
#     Region: "zone_6"	RelError: 5.08439e-01	AbsError: 4.44908e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.82318e-02	AbsError: 2.22456e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.23643e-01	AbsError: 2.22452e+16
#       Equation: "PotentialEquation"	RelError: 1.66564e-01	AbsError: 5.57664e-02
# Iteration: 5
#   Device: "device"	RelError: 1.40064e+04	AbsError: 1.90595e+18
#     Region: "zone_1"	RelError: 1.99859e+03	AbsError: 1.90595e+18
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 6.90868e+13
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.90588e+18
#       Equation: "PotentialEquation"	RelError: 5.91746e-01	AbsError: 1.01843e-01
#     Region: "zone_2"	RelError: 5.36541e+03	AbsError: 4.45126e+17
#       Equation: "ElectronContinuityEquation"	RelError: 1.14550e+03	AbsError: 4.45126e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.00789e+05
#       Equation: "PotentialEquation"	RelError: 3.22092e+03	AbsError: 7.97113e-02
#     Region: "zone_3"	RelError: 9.99876e+02	AbsError: 1.94085e+17
#       Equation: "ElectronContinuityEquation"	RelError: 4.23771e-01	AbsError: 1.33944e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 6.01411e+16
#       Equation: "PotentialEquation"	RelError: 4.52351e-01	AbsError: 6.96611e-02
#     Region: "zone_4"	RelError: 4.64294e+03	AbsError: 6.31814e+16
#       Equation: "ElectronContinuityEquation"	RelError: 4.64276e+03	AbsError: 7.92677e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.25237e-01	AbsError: 5.52546e+16
#       Equation: "PotentialEquation"	RelError: 5.92562e-02	AbsError: 2.57826e-02
#     Region: "zone_5"	RelError: 9.99127e+02	AbsError: 5.53077e+14
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.95830e+13
#       Equation: "HoleContinuityEquation"	RelError: 4.78501e-04	AbsError: 5.33494e+14
#       Equation: "PotentialEquation"	RelError: 1.26115e-01	AbsError: 4.83200e-02
#     Region: "zone_6"	RelError: 3.99350e-01	AbsError: 3.78881e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.75329e-02	AbsError: 1.88449e+16
#       Equation: "HoleContinuityEquation"	RelError: 2.55709e-01	AbsError: 1.90432e+16
#       Equation: "PotentialEquation"	RelError: 1.26109e-01	AbsError: 4.83147e-02
# Iteration: 6
#   Device: "device"	RelError: 8.68173e+03	AbsError: 2.24018e+18
#     Region: "zone_1"	RelError: 2.43853e+03	AbsError: 2.24018e+18
#       Equation: "ElectronContinuityEquation"	RelError: 1.43926e+03	AbsError: 3.09777e+13
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 2.24015e+18
#       Equation: "PotentialEquation"	RelError: 2.74979e-01	AbsError: 8.40033e-02
#     Region: "zone_2"	RelError: 3.24526e+03	AbsError: 1.96192e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.96192e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.00789e+02
#       Equation: "PotentialEquation"	RelError: 1.24726e+03	AbsError: 7.52599e-02
#     Region: "zone_3"	RelError: 9.99490e+02	AbsError: 1.03880e+17
#       Equation: "ElectronContinuityEquation"	RelError: 1.92031e-01	AbsError: 6.72920e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 3.65881e+16
#       Equation: "PotentialEquation"	RelError: 2.98390e-01	AbsError: 6.54942e-02
#     Region: "zone_4"	RelError: 9.99055e+02	AbsError: 6.73775e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 2.46323e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.55293e-02	AbsError: 4.27452e+15
#       Equation: "PotentialEquation"	RelError: 3.94355e-02	AbsError: 1.75583e-02
#     Region: "zone_5"	RelError: 9.99094e+02	AbsError: 4.14027e+14
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.22479e+12
#       Equation: "HoleContinuityEquation"	RelError: 3.93726e-04	AbsError: 4.08802e+14
#       Equation: "PotentialEquation"	RelError: 9.34455e-02	AbsError: 3.94934e-02
#     Region: "zone_6"	RelError: 3.01866e-01	AbsError: 2.36130e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.10704e-02	AbsError: 1.17685e+16
#       Equation: "HoleContinuityEquation"	RelError: 1.97359e-01	AbsError: 1.18445e+16
#       Equation: "PotentialEquation"	RelError: 9.34370e-02	AbsError: 3.94871e-02
# Iteration: 7
#   Device: "device"	RelError: 7.10825e+03	AbsError: 5.33664e+17
#     Region: "zone_1"	RelError: 3.98649e+03	AbsError: 5.33664e+17
#       Equation: "ElectronContinuityEquation"	RelError: 2.98638e+03	AbsError: 2.01217e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.33462e+17
#       Equation: "PotentialEquation"	RelError: 1.11370e+00	AbsError: 5.83975e-02
#     Region: "zone_2"	RelError: 1.12186e+03	AbsError: 6.15503e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.00000e+00	AbsError: 6.15503e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.00789e-01
#       Equation: "PotentialEquation"	RelError: 1.21865e+02	AbsError: 7.14148e-02
#     Region: "zone_3"	RelError: 9.99297e+02	AbsError: 5.86717e+16
#       Equation: "ElectronContinuityEquation"	RelError: 8.15080e-02	AbsError: 3.10968e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 2.75749e+16
#       Equation: "PotentialEquation"	RelError: 2.15184e-01	AbsError: 6.01814e-02
#     Region: "zone_4"	RelError: 9.99006e+02	AbsError: 1.74644e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 2.46323e+12
#       Equation: "HoleContinuityEquation"	RelError: 2.85972e-03	AbsError: 1.74397e+15
#       Equation: "PotentialEquation"	RelError: 3.25773e-03	AbsError: 1.49608e-03
#     Region: "zone_5"	RelError: 1.23728e+00	AbsError: 3.73960e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.17261e+00	AbsError: 3.30064e+12
#       Equation: "HoleContinuityEquation"	RelError: 3.56562e-04	AbsError: 3.70660e+14
#       Equation: "PotentialEquation"	RelError: 6.43103e-02	AbsError: 2.90479e-02
#     Region: "zone_6"	RelError: 3.47139e-01	AbsError: 1.65049e+16
#       Equation: "ElectronContinuityEquation"	RelError: 7.80047e-03	AbsError: 8.22820e+15
#       Equation: "HoleContinuityEquation"	RelError: 2.75039e-01	AbsError: 8.27666e+15
#       Equation: "PotentialEquation"	RelError: 6.42991e-02	AbsError: 2.90405e-02
# Iteration: 8
#   Device: "device"	RelError: 8.74373e+03	AbsError: 3.45216e+17
#     Region: "zone_1"	RelError: 3.58396e+03	AbsError: 3.45216e+17
#       Equation: "ElectronContinuityEquation"	RelError: 1.42457e+03	AbsError: 2.01016e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 3.45015e+17
#       Equation: "PotentialEquation"	RelError: 1.16039e+03	AbsError: 4.41294e-02
#     Region: "zone_2"	RelError: 3.15819e+03	AbsError: 6.48781e+16
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 6.48781e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.98801e+02	AbsError: 5.00789e-04
#       Equation: "PotentialEquation"	RelError: 1.16039e+03	AbsError: 6.68678e-02
#     Region: "zone_3"	RelError: 9.99245e+02	AbsError: 7.89713e+16
#       Equation: "ElectronContinuityEquation"	RelError: 8.36873e-02	AbsError: 3.72510e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 4.17203e+16
#       Equation: "PotentialEquation"	RelError: 1.61029e-01	AbsError: 5.36806e-02
#     Region: "zone_4"	RelError: 9.99006e+02	AbsError: 9.29370e+14
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.05323e+12
#       Equation: "HoleContinuityEquation"	RelError: 2.25186e-03	AbsError: 9.28317e+14
#       Equation: "PotentialEquation"	RelError: 3.53584e-03	AbsError: 1.61808e-03
#     Region: "zone_5"	RelError: 2.86756e+00	AbsError: 4.50031e+14
#       Equation: "ElectronContinuityEquation"	RelError: 2.81557e+00	AbsError: 2.50971e+12
#       Equation: "HoleContinuityEquation"	RelError: 4.30315e-04	AbsError: 4.47521e+14
#       Equation: "PotentialEquation"	RelError: 5.15586e-02	AbsError: 2.45542e-02
#     Region: "zone_6"	RelError: 4.58132e-01	AbsError: 2.04397e+16
#       Equation: "ElectronContinuityEquation"	RelError: 9.74218e-03	AbsError: 1.01772e+16
#       Equation: "HoleContinuityEquation"	RelError: 3.96858e-01	AbsError: 1.02625e+16
#       Equation: "PotentialEquation"	RelError: 5.15321e-02	AbsError: 2.45389e-02
# Iteration: 9
#   Device: "device"	RelError: 3.77498e+06	AbsError: 2.27869e+17
#     Region: "zone_1"	RelError: 3.23306e+03	AbsError: 2.27869e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 7.65464e+11
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 2.27868e+17
#       Equation: "PotentialEquation"	RelError: 1.23506e+03	AbsError: 3.77397e-02
#     Region: "zone_2"	RelError: 3.21405e+03	AbsError: 3.59949e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.14613e+03	AbsError: 3.59949e+16
#       Equation: "HoleContinuityEquation"	RelError: 8.32857e+02	AbsError: 5.00789e-07
#       Equation: "PotentialEquation"	RelError: 1.23506e+03	AbsError: 6.09669e-02
#     Region: "zone_3"	RelError: 9.99301e+02	AbsError: 1.45984e+17
#       Equation: "ElectronContinuityEquation"	RelError: 1.81494e-01	AbsError: 6.91363e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 7.68474e+16
#       Equation: "PotentialEquation"	RelError: 1.19957e-01	AbsError: 4.54403e-02
#     Region: "zone_4"	RelError: 1.28408e+04	AbsError: 1.12739e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.28408e+04	AbsError: 1.05218e+12
#       Equation: "HoleContinuityEquation"	RelError: 1.74678e-04	AbsError: 1.11686e+14
#       Equation: "PotentialEquation"	RelError: 5.03657e-03	AbsError: 2.29298e-03
#     Region: "zone_5"	RelError: 3.75469e+06	AbsError: 3.52875e+12
#       Equation: "ElectronContinuityEquation"	RelError: 3.75469e+06	AbsError: 1.01888e+12
#       Equation: "HoleContinuityEquation"	RelError: 2.42656e-06	AbsError: 2.50987e+12
#       Equation: "PotentialEquation"	RelError: 6.48001e-04	AbsError: 3.17827e-04
#     Region: "zone_6"	RelError: 1.46498e+00	AbsError: 3.34833e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.62119e-02	AbsError: 1.66656e+16
#       Equation: "HoleContinuityEquation"	RelError: 1.44790e+00	AbsError: 1.68177e+16
#       Equation: "PotentialEquation"	RelError: 8.69722e-04	AbsError: 4.14796e-04
# Iteration: 10
#   Device: "device"	RelError: 5.93298e+05	AbsError: 1.97464e+17
#     Region: "zone_1"	RelError: 1.66665e+05	AbsError: 4.23620e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.65387e+05	AbsError: 5.30007e+12
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 4.23567e+16
#       Equation: "PotentialEquation"	RelError: 2.78622e+02	AbsError: 2.66550e-02
#     Region: "zone_2"	RelError: 1.65006e+02	AbsError: 9.10386e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.99998e-01	AbsError: 9.10386e+15
#       Equation: "HoleContinuityEquation"	RelError: 4.98291e+00	AbsError: 5.00789e-10
#       Equation: "PotentialEquation"	RelError: 1.59023e+02	AbsError: 5.41228e-02
#     Region: "zone_3"	RelError: 9.99402e+02	AbsError: 1.97464e+17
#       Equation: "ElectronContinuityEquation"	RelError: 3.16140e-01	AbsError: 9.14810e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.05983e+17
#       Equation: "PotentialEquation"	RelError: 8.58435e-02	AbsError: 3.55719e-02
#     Region: "zone_4"	RelError: 4.06258e+05	AbsError: 6.07444e+13
#       Equation: "ElectronContinuityEquation"	RelError: 4.06258e+05	AbsError: 9.61106e+09
#       Equation: "HoleContinuityEquation"	RelError: 1.57922e-04	AbsError: 6.07348e+13
#       Equation: "PotentialEquation"	RelError: 5.64862e-03	AbsError: 2.55727e-03
#     Region: "zone_5"	RelError: 1.92094e+04	AbsError: 3.32234e+12
#       Equation: "ElectronContinuityEquation"	RelError: 1.92094e+04	AbsError: 1.84672e+09
#       Equation: "HoleContinuityEquation"	RelError: 3.21027e-06	AbsError: 3.32049e+12
#       Equation: "PotentialEquation"	RelError: 7.22258e-04	AbsError: 3.53992e-04
#     Region: "zone_6"	RelError: 2.06013e+00	AbsError: 3.75237e+16
#       Equation: "ElectronContinuityEquation"	RelError: 1.85047e-02	AbsError: 1.86771e+16
#       Equation: "HoleContinuityEquation"	RelError: 2.04064e+00	AbsError: 1.88466e+16
#       Equation: "PotentialEquation"	RelError: 9.92878e-04	AbsError: 4.73063e-04
# Iteration: 11
#   Device: "device"	RelError: 2.52694e+04	AbsError: 1.53819e+17
#     Region: "zone_1"	RelError: 1.20571e+03	AbsError: 2.26520e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 5.29497e+12
#       Equation: "HoleContinuityEquation"	RelError: 1.00000e+00	AbsError: 2.25990e+15
#       Equation: "PotentialEquation"	RelError: 2.05713e+02	AbsError: 2.13471e-02
#     Region: "zone_2"	RelError: 1.53802e+03	AbsError: 4.35128e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.33231e+03	AbsError: 4.35128e+15
#       Equation: "HoleContinuityEquation"	RelError: 5.00786e-03	AbsError: 5.00789e-13
#       Equation: "PotentialEquation"	RelError: 2.05713e+02	AbsError: 4.64637e-02
#     Region: "zone_3"	RelError: 9.96180e+02	AbsError: 1.53819e+17
#       Equation: "ElectronContinuityEquation"	RelError: 3.01566e-01	AbsError: 6.70451e+16
#       Equation: "HoleContinuityEquation"	RelError: 9.95820e+02	AbsError: 8.67743e+16
#       Equation: "PotentialEquation"	RelError: 5.79902e-02	AbsError: 2.58883e-02
#     Region: "zone_4"	RelError: 9.99003e+02	AbsError: 4.49767e+13
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 9.61106e+06
#       Equation: "HoleContinuityEquation"	RelError: 1.16962e-04	AbsError: 4.49767e+13
#       Equation: "PotentialEquation"	RelError: 2.76774e-03	AbsError: 1.24959e-03
#     Region: "zone_5"	RelError: 2.04514e+04	AbsError: 1.61051e+12
#       Equation: "ElectronContinuityEquation"	RelError: 2.04514e+04	AbsError: 1.84672e+06
#       Equation: "HoleContinuityEquation"	RelError: 1.55705e-06	AbsError: 1.61051e+12
#       Equation: "PotentialEquation"	RelError: 3.50208e-04	AbsError: 1.71583e-04
#     Region: "zone_6"	RelError: 7.90275e+01	AbsError: 1.88097e+16
#       Equation: "ElectronContinuityEquation"	RelError: 9.36486e-03	AbsError: 9.36439e+15
#       Equation: "HoleContinuityEquation"	RelError: 7.90177e+01	AbsError: 9.44531e+15
#       Equation: "PotentialEquation"	RelError: 5.12877e-04	AbsError: 2.44238e-04
# Iteration: 12
#   Device: "device"	RelError: 4.52462e+04	AbsError: 3.53069e+16
#     Region: "zone_1"	RelError: 2.69600e+02	AbsError: 2.06516e+14
#       Equation: "ElectronContinuityEquation"	RelError: 2.67381e+02	AbsError: 3.79053e+11
#       Equation: "HoleContinuityEquation"	RelError: 1.00000e+00	AbsError: 2.06137e+14
#       Equation: "PotentialEquation"	RelError: 1.21868e+00	AbsError: 3.31915e-04
#     Region: "zone_2"	RelError: 3.21646e+00	AbsError: 2.21944e+15
#       Equation: "ElectronContinuityEquation"	RelError: 9.97773e-01	AbsError: 2.21926e+15
#       Equation: "HoleContinuityEquation"	RelError: 1.00000e+00	AbsError: 1.81755e+11
#       Equation: "PotentialEquation"	RelError: 1.21868e+00	AbsError: 3.72389e-02
#     Region: "zone_3"	RelError: 4.39483e+04	AbsError: 3.53069e+16
#       Equation: "ElectronContinuityEquation"	RelError: 6.04354e-02	AbsError: 1.26739e+16
#       Equation: "HoleContinuityEquation"	RelError: 4.39482e+04	AbsError: 2.26330e+16
#       Equation: "PotentialEquation"	RelError: 3.63607e-02	AbsError: 1.65694e-02
#     Region: "zone_4"	RelError: 1.28425e+01	AbsError: 5.82017e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.28424e+01	AbsError: 8.92202e+03
#       Equation: "HoleContinuityEquation"	RelError: 1.51354e-06	AbsError: 5.82017e+11
#       Equation: "PotentialEquation"	RelError: 3.66196e-05	AbsError: 1.65326e-05
#     Region: "zone_5"	RelError: 1.33204e+01	AbsError: 2.13216e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.33204e+01	AbsError: 1.71894e+03
#       Equation: "HoleContinuityEquation"	RelError: 2.06138e-08	AbsError: 2.13216e+10
#       Equation: "PotentialEquation"	RelError: 4.63137e-06	AbsError: 2.26912e-06
#     Region: "zone_6"	RelError: 9.99000e+02	AbsError: 3.45264e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.73479e-04	AbsError: 1.73440e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.71824e+14
#       Equation: "PotentialEquation"	RelError: 1.18391e-05	AbsError: 5.63785e-06
# Iteration: 13
#   Device: "device"	RelError: 4.70978e+05	AbsError: 1.91384e+15
#     Region: "zone_1"	RelError: 5.79091e+00	AbsError: 1.04526e+14
#       Equation: "ElectronContinuityEquation"	RelError: 1.77165e+00	AbsError: 2.40987e+11
#       Equation: "HoleContinuityEquation"	RelError: 3.54176e+00	AbsError: 1.04285e+14
#       Equation: "PotentialEquation"	RelError: 4.77489e-01	AbsError: 1.43046e-04
#     Region: "zone_2"	RelError: 2.85394e+03	AbsError: 1.62839e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.81790e+00	AbsError: 1.62820e+15
#       Equation: "HoleContinuityEquation"	RelError: 2.85164e+03	AbsError: 1.81573e+11
#       Equation: "PotentialEquation"	RelError: 4.77489e-01	AbsError: 2.64035e-02
#     Region: "zone_3"	RelError: 4.60859e+05	AbsError: 1.91384e+15
#       Equation: "ElectronContinuityEquation"	RelError: 2.70870e-03	AbsError: 5.66507e+14
#       Equation: "HoleContinuityEquation"	RelError: 4.60859e+05	AbsError: 1.34733e+15
#       Equation: "PotentialEquation"	RelError: 3.36179e-04	AbsError: 1.46493e-04
#     Region: "zone_4"	RelError: 1.08909e+00	AbsError: 8.32523e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.08909e+00	AbsError: 3.72876e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.28253e-07	AbsError: 8.32523e+10
#       Equation: "PotentialEquation"	RelError: 7.36004e-07	AbsError: 3.32297e-07
#     Region: "zone_5"	RelError: 3.30568e-01	AbsError: 4.27372e+08
#       Equation: "ElectronContinuityEquation"	RelError: 3.30568e-01	AbsError: 3.00590e+01
#       Equation: "HoleContinuityEquation"	RelError: 4.13184e-10	AbsError: 4.27372e+08
#       Equation: "PotentialEquation"	RelError: 9.29386e-08	AbsError: 4.55348e-08
#     Region: "zone_6"	RelError: 7.25837e+03	AbsError: 2.64812e+12
#       Equation: "ElectronContinuityEquation"	RelError: 2.47670e-06	AbsError: 2.47615e+12
#       Equation: "HoleContinuityEquation"	RelError: 7.25837e+03	AbsError: 1.71972e+11
#       Equation: "PotentialEquation"	RelError: 1.32922e-07	AbsError: 6.32982e-08
# Iteration: 14
#   Device: "device"	RelError: 8.99761e+04	AbsError: 1.44376e+15
#     Region: "zone_1"	RelError: 6.87728e-01	AbsError: 4.32133e+13
#       Equation: "ElectronContinuityEquation"	RelError: 1.23515e-01	AbsError: 5.07349e+09
#       Equation: "HoleContinuityEquation"	RelError: 3.25108e-01	AbsError: 4.32082e+13
#       Equation: "PotentialEquation"	RelError: 2.39105e-01	AbsError: 5.74108e-05
#     Region: "zone_2"	RelError: 8.77448e+04	AbsError: 1.44376e+15
#       Equation: "ElectronContinuityEquation"	RelError: 1.41289e-01	AbsError: 1.44373e+15
#       Equation: "HoleContinuityEquation"	RelError: 8.77444e+04	AbsError: 2.86729e+10
#       Equation: "PotentialEquation"	RelError: 2.39105e-01	AbsError: 1.94232e-02
#     Region: "zone_3"	RelError: 9.99000e+02	AbsError: 1.84696e+14
#       Equation: "ElectronContinuityEquation"	RelError: 3.99891e-04	AbsError: 1.80784e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 3.91189e+12
#       Equation: "PotentialEquation"	RelError: 2.15583e-05	AbsError: 9.48579e-06
#     Region: "zone_4"	RelError: 4.69220e-02	AbsError: 3.28841e+10
#       Equation: "ElectronContinuityEquation"	RelError: 4.69220e-02	AbsError: 1.55822e+01
#       Equation: "HoleContinuityEquation"	RelError: 5.06589e-08	AbsError: 3.28841e+10
#       Equation: "PotentialEquation"	RelError: 2.79591e-09	AbsError: 1.30021e-09
#     Region: "zone_5"	RelError: 1.40858e-02	AbsError: 1.78449e+04
#       Equation: "ElectronContinuityEquation"	RelError: 1.40858e-02	AbsError: 1.26299e+00
#       Equation: "HoleContinuityEquation"	RelError: 1.72513e-14	AbsError: 1.78436e+04
#       Equation: "PotentialEquation"	RelError: 3.88217e-12	AbsError: 1.90205e-12
#     Region: "zone_6"	RelError: 1.23153e+03	AbsError: 4.99935e+07
#       Equation: "ElectronContinuityEquation"	RelError: 2.61810e-11	AbsError: 2.61752e+07
#       Equation: "HoleContinuityEquation"	RelError: 1.23153e+03	AbsError: 2.38183e+07
#       Equation: "PotentialEquation"	RelError: 2.45565e-12	AbsError: 1.16939e-12
# Iteration: 15
#   Device: "device"	RelError: 1.71671e+09	AbsError: 4.94005e+14
#     Region: "zone_1"	RelError: 1.95792e-01	AbsError: 2.95323e+13
#       Equation: "ElectronContinuityEquation"	RelError: 2.77872e-02	AbsError: 4.17388e+09
#       Equation: "HoleContinuityEquation"	RelError: 2.14939e-03	AbsError: 2.95282e+13
#       Equation: "PotentialEquation"	RelError: 1.65855e-01	AbsError: 4.13377e-05
#     Region: "zone_2"	RelError: 2.28198e+06	AbsError: 4.94005e+14
#       Equation: "ElectronContinuityEquation"	RelError: 3.56607e-02	AbsError: 4.94005e+14
#       Equation: "HoleContinuityEquation"	RelError: 2.28198e+06	AbsError: 2.87008e+07
#       Equation: "PotentialEquation"	RelError: 1.65855e-01	AbsError: 6.56463e-05
#     Region: "zone_3"	RelError: 1.71442e+09	AbsError: 6.28783e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.38221e-06	AbsError: 6.24871e+11
#       Equation: "HoleContinuityEquation"	RelError: 1.71442e+09	AbsError: 3.91189e+09
#       Equation: "PotentialEquation"	RelError: 6.18433e-07	AbsError: 2.72115e-07
#     Region: "zone_4"	RelError: 9.86667e-03	AbsError: 1.96428e+10
#       Equation: "ElectronContinuityEquation"	RelError: 9.86664e-03	AbsError: 3.18815e+00
#       Equation: "HoleContinuityEquation"	RelError: 3.02603e-08	AbsError: 1.96428e+10
#       Equation: "PotentialEquation"	RelError: 1.68293e-09	AbsError: 7.82632e-10
#     Region: "zone_5"	RelError: 2.87320e-03	AbsError: 4.35154e+02
#       Equation: "ElectronContinuityEquation"	RelError: 2.87320e-03	AbsError: 2.58365e-01
#       Equation: "HoleContinuityEquation"	RelError: 3.87054e-16	AbsError: 4.34895e+02
#       Equation: "PotentialEquation"	RelError: 9.69381e-14	AbsError: 4.74943e-14
#     Region: "zone_6"	RelError: 5.02092e+02	AbsError: 2.58746e+06
#       Equation: "ElectronContinuityEquation"	RelError: 2.56424e-12	AbsError: 2.56367e+06
#       Equation: "HoleContinuityEquation"	RelError: 5.02092e+02	AbsError: 2.37862e+04
#       Equation: "PotentialEquation"	RelError: 1.36789e-13	AbsError: 6.51400e-14
# Iteration: 16
#   Device: "device"	RelError: 8.23813e+03	AbsError: 1.27559e+11
#     Region: "zone_1"	RelError: 5.80241e-05	AbsError: 2.61105e+09
#       Equation: "ElectronContinuityEquation"	RelError: 4.59500e-05	AbsError: 2.07360e+06
#       Equation: "HoleContinuityEquation"	RelError: 1.14881e-06	AbsError: 2.60898e+09
#       Equation: "PotentialEquation"	RelError: 1.09253e-05	AbsError: 3.65580e-09
#     Region: "zone_2"	RelError: 4.90391e+01	AbsError: 1.27559e+11
#       Equation: "ElectronContinuityEquation"	RelError: 1.39862e-05	AbsError: 1.27559e+11
#       Equation: "HoleContinuityEquation"	RelError: 4.90390e+01	AbsError: 1.87984e+04
#       Equation: "PotentialEquation"	RelError: 1.09253e-05	AbsError: 8.97041e-09
#     Region: "zone_3"	RelError: 8.18861e+03	AbsError: 5.09604e+07
#       Equation: "ElectronContinuityEquation"	RelError: 1.04063e-10	AbsError: 4.70451e+07
#       Equation: "HoleContinuityEquation"	RelError: 8.18861e+03	AbsError: 3.91533e+06
#       Equation: "PotentialEquation"	RelError: 5.61038e-11	AbsError: 2.46861e-11
#     Region: "zone_4"	RelError: 1.83914e-05	AbsError: 2.06313e+06
#       Equation: "ElectronContinuityEquation"	RelError: 1.83914e-05	AbsError: 5.86314e-03
#       Equation: "HoleContinuityEquation"	RelError: 3.17831e-12	AbsError: 2.06313e+06
#       Equation: "PotentialEquation"	RelError: 1.76600e-13	AbsError: 8.21261e-14
#     Region: "zone_5"	RelError: 5.28391e-06	AbsError: 1.54749e+02
#       Equation: "ElectronContinuityEquation"	RelError: 5.28391e-06	AbsError: 4.75144e-04
#       Equation: "HoleContinuityEquation"	RelError: 1.10603e-16	AbsError: 1.54749e+02
#       Equation: "PotentialEquation"	RelError: 7.10525e-17	AbsError: 3.39302e-17
#     Region: "zone_6"	RelError: 4.75959e-01	AbsError: 2.18809e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.17027e-16	AbsError: 1.75424e+02
#       Equation: "HoleContinuityEquation"	RelError: 4.75959e-01	AbsError: 4.33857e+01
#       Equation: "PotentialEquation"	RelError: 1.90274e-16	AbsError: 9.26019e-17
# Iteration: 17
#   Device: "device"	RelError: 4.64854e-07	AbsError: 7.24169e+03
#     Region: "zone_1"	RelError: 3.50979e-12	AbsError: 1.07338e+02
#       Equation: "ElectronContinuityEquation"	RelError: 3.04773e-12	AbsError: 5.29310e-02
#       Equation: "HoleContinuityEquation"	RelError: 5.04151e-14	AbsError: 1.07285e+02
#       Equation: "PotentialEquation"	RelError: 4.11640e-13	AbsError: 1.69442e-16
#     Region: "zone_2"	RelError: 4.30942e-07	AbsError: 7.24169e+03
#       Equation: "ElectronContinuityEquation"	RelError: 4.80859e-13	AbsError: 7.24169e+03
#       Equation: "HoleContinuityEquation"	RelError: 4.30941e-07	AbsError: 3.27394e-04
#       Equation: "PotentialEquation"	RelError: 4.11640e-13	AbsError: 4.59170e-16
#     Region: "zone_3"	RelError: 2.70454e-08	AbsError: 1.34640e+02
#       Equation: "ElectronContinuityEquation"	RelError: 2.09583e-16	AbsError: 1.34640e+02
#       Equation: "HoleContinuityEquation"	RelError: 2.70454e-08	AbsError: 1.09723e-05
#       Equation: "PotentialEquation"	RelError: 8.30810e-17	AbsError: 3.62038e-17
#     Region: "zone_4"	RelError: 1.37102e-12	AbsError: 1.45975e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.37079e-12	AbsError: 4.15449e-10
#       Equation: "HoleContinuityEquation"	RelError: 1.66275e-16	AbsError: 1.45975e+02
#       Equation: "PotentialEquation"	RelError: 6.75381e-17	AbsError: 3.12194e-17
#     Region: "zone_5"	RelError: 3.74635e-13	AbsError: 1.39196e+02
#       Equation: "ElectronContinuityEquation"	RelError: 3.74475e-13	AbsError: 3.36680e-11
#       Equation: "HoleContinuityEquation"	RelError: 9.90353e-17	AbsError: 1.39196e+02
#       Equation: "PotentialEquation"	RelError: 6.07817e-17	AbsError: 2.95777e-17
#     Region: "zone_6"	RelError: 6.86080e-09	AbsError: 1.37540e+02
#       Equation: "ElectronContinuityEquation"	RelError: 9.17566e-17	AbsError: 1.37540e+02
#       Equation: "HoleContinuityEquation"	RelError: 6.86080e-09	AbsError: 6.25392e-07
#       Equation: "PotentialEquation"	RelError: 6.44353e-17	AbsError: 3.13124e-17
# Iteration: 18
#   Device: "device"	RelError: 1.33585e-13	AbsError: 1.41481e+02
#     Region: "zone_1"	RelError: 6.35729e-14	AbsError: 6.49341e+01
#       Equation: "ElectronContinuityEquation"	RelError: 4.10903e-15	AbsError: 3.03361e-04
#       Equation: "HoleContinuityEquation"	RelError: 1.72695e-15	AbsError: 6.49338e+01
#       Equation: "PotentialEquation"	RelError: 5.77369e-14	AbsError: 3.31006e-17
#     Region: "zone_2"	RelError: 6.77603e-14	AbsError: 1.06739e+02
#       Equation: "ElectronContinuityEquation"	RelError: 6.47407e-15	AbsError: 1.06739e+02
#       Equation: "HoleContinuityEquation"	RelError: 3.54937e-15	AbsError: 6.70855e-06
#       Equation: "PotentialEquation"	RelError: 5.77369e-14	AbsError: 3.16841e-17
#     Region: "zone_3"	RelError: 6.10660e-16	AbsError: 1.35831e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.45250e-16	AbsError: 1.35831e+02
#       Equation: "HoleContinuityEquation"	RelError: 3.97424e-16	AbsError: 1.54614e-13
#       Equation: "PotentialEquation"	RelError: 6.79854e-17	AbsError: 3.07078e-17
#     Region: "zone_4"	RelError: 8.66006e-16	AbsError: 1.41481e+02
#       Equation: "ElectronContinuityEquation"	RelError: 6.53836e-16	AbsError: 2.02247e-13
#       Equation: "HoleContinuityEquation"	RelError: 1.44766e-16	AbsError: 1.41481e+02
#       Equation: "PotentialEquation"	RelError: 6.74038e-17	AbsError: 2.98692e-17
#     Region: "zone_5"	RelError: 3.53725e-16	AbsError: 1.37539e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.93953e-16	AbsError: 1.93090e-14
#       Equation: "HoleContinuityEquation"	RelError: 9.93921e-17	AbsError: 1.37539e+02
#       Equation: "PotentialEquation"	RelError: 6.03801e-17	AbsError: 2.87560e-17
#     Region: "zone_6"	RelError: 4.21668e-16	AbsError: 1.34197e+02
#       Equation: "ElectronContinuityEquation"	RelError: 8.95251e-17	AbsError: 1.34197e+02
#       Equation: "HoleContinuityEquation"	RelError: 2.71490e-16	AbsError: 2.06537e-14
#       Equation: "PotentialEquation"	RelError: 6.06532e-17	AbsError: 2.88844e-17
# Built-in potential:  0.9524237402534694
# Solving for 0.21052631578947367 bias
# number of equations 82026
# Iteration: 0
#   Device: "device"	RelError: 4.22752e+04	AbsError: 1.00394e+17
#     Region: "zone_1"	RelError: 2.25295e+03	AbsError: 9.19893e+16
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.52318e+11
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 9.19891e+16
#       Equation: "PotentialEquation"	RelError: 2.54952e+02	AbsError: 4.50381e-02
#     Region: "zone_2"	RelError: 1.99918e+03	AbsError: 1.00394e+17
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.00394e+17
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.28542e+10
#       Equation: "PotentialEquation"	RelError: 1.18155e+00	AbsError: 5.72751e-02
#     Region: "zone_3"	RelError: 9.99117e+02	AbsError: 1.53012e+14
#       Equation: "ElectronContinuityEquation"	RelError: 3.38576e-04	AbsError: 1.53012e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 4.82258e+02
#       Equation: "PotentialEquation"	RelError: 1.16227e-01	AbsError: 5.72751e-02
#     Region: "zone_4"	RelError: 9.99000e+02	AbsError: 6.66780e+13
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 3.75715e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.02730e-04	AbsError: 6.66780e+13
#       Equation: "PotentialEquation"	RelError: 5.71030e-06	AbsError: 2.65551e-06
#     Region: "zone_5"	RelError: 9.99000e+02	AbsError: 3.88869e+02
#       Equation: "ElectronContinuityEquation"	RelError: 9.99000e+02	AbsError: 9.98002e+01
#       Equation: "HoleContinuityEquation"	RelError: 2.88483e-16	AbsError: 2.89069e+02
#       Equation: "PotentialEquation"	RelError: 4.90227e-15	AbsError: 2.40184e-15
#     Region: "zone_6"	RelError: 3.50259e+04	AbsError: 7.23225e+03
#       Equation: "ElectronContinuityEquation"	RelError: 7.10510e-15	AbsError: 7.13209e+03
# ...
#       Equation: "ElectronContinuityEquation"	RelError: 9.98706e-01	AbsError: 5.66333e+02
#       Equation: "HoleContinuityEquation"	RelError: 2.84564e-14	AbsError: 2.85142e+04
#       Equation: "PotentialEquation"	RelError: 2.27454e-13	AbsError: 1.11440e-13
#     Region: "zone_6"	RelError: 1.08795e+00	AbsError: 1.94633e+05
#       Equation: "ElectronContinuityEquation"	RelError: 1.93020e-13	AbsError: 1.92868e+05
#       Equation: "HoleContinuityEquation"	RelError: 9.99614e-01	AbsError: 1.76446e+03
#       Equation: "PotentialEquation"	RelError: 8.83319e-02	AbsError: 3.60165e-02
# Iteration: 4
#   Device: "device"	RelError: 9.44489e+06	AbsError: 2.83978e+14
#     Region: "zone_1"	RelError: 9.42387e+06	AbsError: 5.27303e+12
#       Equation: "ElectronContinuityEquation"	RelError: 9.42387e+06	AbsError: 5.85470e+11
#       Equation: "HoleContinuityEquation"	RelError: 1.38753e+00	AbsError: 4.68756e+12
#       Equation: "PotentialEquation"	RelError: 1.40098e-01	AbsError: 8.63963e-06
#     Region: "zone_2"	RelError: 6.69076e+03	AbsError: 2.83978e+14
#       Equation: "ElectronContinuityEquation"	RelError: 2.83919e+03	AbsError: 2.83960e+14
#       Equation: "HoleContinuityEquation"	RelError: 3.85144e+03	AbsError: 1.80567e+10
#       Equation: "PotentialEquation"	RelError: 1.35255e-01	AbsError: 2.58356e-02
#     Region: "zone_3"	RelError: 9.99064e+02	AbsError: 8.61865e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.90635e-07	AbsError: 8.61865e+10
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 2.42583e+04
#       Equation: "PotentialEquation"	RelError: 6.37930e-02	AbsError: 2.50119e-02
#     Region: "zone_4"	RelError: 1.23232e+04	AbsError: 9.91068e+07
#       Equation: "ElectronContinuityEquation"	RelError: 1.23232e+04	AbsError: 6.52425e+03
#       Equation: "HoleContinuityEquation"	RelError: 1.52665e-10	AbsError: 9.91003e+07
#       Equation: "PotentialEquation"	RelError: 1.29909e-11	AbsError: 6.04132e-12
#     Region: "zone_5"	RelError: 9.97052e+00	AbsError: 1.11196e+03
#       Equation: "ElectronContinuityEquation"	RelError: 9.97052e+00	AbsError: 5.35035e+02
#       Equation: "HoleContinuityEquation"	RelError: 5.76301e-16	AbsError: 5.76927e+02
#       Equation: "PotentialEquation"	RelError: 1.76677e-13	AbsError: 8.65618e-14
#     Region: "zone_6"	RelError: 9.99058e+02	AbsError: 6.10858e+03
#       Equation: "ElectronContinuityEquation"	RelError: 4.28412e-15	AbsError: 4.27984e+03
#       Equation: "HoleContinuityEquation"	RelError: 9.99000e+02	AbsError: 1.82871e+03
#       Equation: "PotentialEquation"	RelError: 5.77973e-02	AbsError: 2.50119e-02
# Iteration: 5
#   Device: "device"	RelError: 7.00785e+00	AbsError: 1.58883e+14
#     Region: "zone_1"	RelError: 1.13421e+00	AbsError: 6.34498e+12
#       Equation: "ElectronContinuityEquation"	RelError: 9.99999e-01	AbsError: 2.13303e+11
#       Equation: "HoleContinuityEquation"	RelError: 1.35468e-03	AbsError: 6.13168e+12
#       Equation: "PotentialEquation"	RelError: 1.32855e-01	AbsError: 8.78273e-06
#     Region: "zone_2"	RelError: 2.19028e+00	AbsError: 1.58883e+14
#       Equation: "ElectronContinuityEquation"	RelError: 9.98985e-01	AbsError: 1.58882e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.99103e-01	AbsError: 6.13134e+08
#       Equation: "PotentialEquation"	RelError: 1.92195e-01	AbsError: 1.71185e-02
#     Region: "zone_3"	RelError: 1.03415e+00	AbsError: 4.63558e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.02534e-07	AbsError: 4.63558e+10
#       Equation: "HoleContinuityEquation"	RelError: 9.92315e-01	AbsError: 2.41455e+03
#       Equation: "PotentialEquation"	RelError: 4.18341e-02	AbsError: 1.71184e-02
#     Region: "zone_4"	RelError: 9.99491e-01	AbsError: 3.43077e+09
#       Equation: "ElectronContinuityEquation"	RelError: 9.99491e-01	AbsError: 9.73258e+02
#       Equation: "HoleContinuityEquation"	RelError: 5.28513e-09	AbsError: 3.43077e+09
#       Equation: "PotentialEquation"	RelError: 2.93838e-10	AbsError: 1.36647e-10
#     Region: "zone_5"	RelError: 6.13517e-01	AbsError: 2.67467e+02
#       Equation: "ElectronContinuityEquation"	RelError: 6.13517e-01	AbsError: 8.51845e+01
#       Equation: "HoleContinuityEquation"	RelError: 1.53313e-16	AbsError: 1.82282e+02
#       Equation: "PotentialEquation"	RelError: 4.74262e-15	AbsError: 2.32362e-15
#     Region: "zone_6"	RelError: 1.03620e+00	AbsError: 2.63204e+03
#       Equation: "ElectronContinuityEquation"	RelError: 2.39416e-15	AbsError: 2.39213e+03
#       Equation: "HoleContinuityEquation"	RelError: 9.98149e-01	AbsError: 2.39894e+02
#       Equation: "PotentialEquation"	RelError: 3.80518e-02	AbsError: 1.71184e-02
# Iteration: 6
#   Device: "device"	RelError: 2.97153e+00	AbsError: 1.97578e+14
#     Region: "zone_1"	RelError: 1.96693e-01	AbsError: 9.03997e+12
#       Equation: "ElectronContinuityEquation"	RelError: 2.56206e-02	AbsError: 5.41867e+09
#       Equation: "HoleContinuityEquation"	RelError: 5.15005e-04	AbsError: 9.03455e+12
#       Equation: "PotentialEquation"	RelError: 1.70558e-01	AbsError: 1.33172e-05
#     Region: "zone_2"	RelError: 1.26460e+00	AbsError: 1.97578e+14
#       Equation: "ElectronContinuityEquation"	RelError: 2.91834e-02	AbsError: 1.97578e+14
#       Equation: "HoleContinuityEquation"	RelError: 9.30033e-01	AbsError: 5.41852e+06
#       Equation: "PotentialEquation"	RelError: 3.05388e-01	AbsError: 2.25485e-05
#     Region: "zone_3"	RelError: 9.28839e-01	AbsError: 4.87136e+10
#       Equation: "ElectronContinuityEquation"	RelError: 1.07749e-07	AbsError: 4.87136e+10
#       Equation: "HoleContinuityEquation"	RelError: 9.28839e-01	AbsError: 1.15966e+03
#       Equation: "PotentialEquation"	RelError: 3.02976e-08	AbsError: 1.25339e-08
#     Region: "zone_4"	RelError: 1.02212e-02	AbsError: 4.38260e+09
#       Equation: "ElectronContinuityEquation"	RelError: 1.02212e-02	AbsError: 9.25263e+00
#       Equation: "HoleContinuityEquation"	RelError: 6.75144e-09	AbsError: 4.38260e+09
#       Equation: "PotentialEquation"	RelError: 3.75288e-10	AbsError: 1.74524e-10
#     Region: "zone_5"	RelError: 5.37140e-03	AbsError: 1.42050e+02
#       Equation: "ElectronContinuityEquation"	RelError: 5.37140e-03	AbsError: 7.49826e-01
#       Equation: "HoleContinuityEquation"	RelError: 1.05627e-16	AbsError: 1.41301e+02
#       Equation: "PotentialEquation"	RelError: 4.19843e-15	AbsError: 2.05700e-15
#     Region: "zone_6"	RelError: 5.65797e-01	AbsError: 6.90871e+02
#       Equation: "ElectronContinuityEquation"	RelError: 6.07126e-16	AbsError: 6.06519e+02
#       Equation: "HoleContinuityEquation"	RelError: 5.65797e-01	AbsError: 8.43524e+01
#       Equation: "PotentialEquation"	RelError: 1.02401e-14	AbsError: 4.71238e-15
# Iteration: 7
#   Device: "device"	RelError: 6.96850e-04	AbsError: 1.62491e+10
#     Region: "zone_1"	RelError: 1.74609e-05	AbsError: 1.87882e+08
#       Equation: "ElectronContinuityEquation"	RelError: 1.48819e-05	AbsError: 1.15498e+06
#       Equation: "HoleContinuityEquation"	RelError: 1.24688e-07	AbsError: 1.86727e+08
#       Equation: "PotentialEquation"	RelError: 2.45430e-06	AbsError: 2.07249e-10
#     Region: "zone_2"	RelError: 4.14655e-04	AbsError: 1.62491e+10
#       Equation: "ElectronContinuityEquation"	RelError: 6.58325e-06	AbsError: 1.62491e+10
#       Equation: "HoleContinuityEquation"	RelError: 4.07806e-04	AbsError: 6.85139e+02
#       Equation: "PotentialEquation"	RelError: 2.65578e-07	AbsError: 6.24234e-10
#     Region: "zone_3"	RelError: 1.63145e-04	AbsError: 1.46047e+06
#       Equation: "ElectronContinuityEquation"	RelError: 3.23041e-12	AbsError: 1.46047e+06
#       Equation: "HoleContinuityEquation"	RelError: 1.63145e-04	AbsError: 1.95726e-01
#       Equation: "PotentialEquation"	RelError: 1.59339e-12	AbsError: 6.59174e-13
#     Region: "zone_4"	RelError: 4.08298e-06	AbsError: 6.45116e+04
#       Equation: "ElectronContinuityEquation"	RelError: 4.08298e-06	AbsError: 3.47986e-03
#       Equation: "HoleContinuityEquation"	RelError: 9.93808e-14	AbsError: 6.45116e+04
#       Equation: "PotentialEquation"	RelError: 5.55682e-15	AbsError: 2.58415e-15
#     Region: "zone_5"	RelError: 2.02014e-06	AbsError: 1.49151e+02
#       Equation: "ElectronContinuityEquation"	RelError: 2.02014e-06	AbsError: 2.82004e-04
#       Equation: "HoleContinuityEquation"	RelError: 1.04488e-16	AbsError: 1.49151e+02
#       Equation: "PotentialEquation"	RelError: 6.47264e-17	AbsError: 3.16777e-17
#     Region: "zone_6"	RelError: 9.54854e-05	AbsError: 1.48111e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.01607e-16	AbsError: 1.48097e+02
#       Equation: "HoleContinuityEquation"	RelError: 9.54854e-05	AbsError: 1.42369e-02
#       Equation: "PotentialEquation"	RelError: 6.93993e-17	AbsError: 3.19465e-17
# Iteration: 8
#   Device: "device"	RelError: 3.30388e-12	AbsError: 1.50125e+02
#     Region: "zone_1"	RelError: 8.18283e-14	AbsError: 1.15907e+02
#       Equation: "ElectronContinuityEquation"	RelError: 5.71083e-14	AbsError: 2.62511e-03
#       Equation: "HoleContinuityEquation"	RelError: 1.41918e-15	AbsError: 1.15904e+02
#       Equation: "PotentialEquation"	RelError: 2.33008e-14	AbsError: 3.23698e-17
#     Region: "zone_2"	RelError: 2.68682e-12	AbsError: 1.10015e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.47382e-14	AbsError: 1.10015e+02
#       Equation: "HoleContinuityEquation"	RelError: 2.60906e-12	AbsError: 4.70449e-06
#       Equation: "PotentialEquation"	RelError: 6.30212e-14	AbsError: 4.11222e-17
#     Region: "zone_3"	RelError: 3.45042e-13	AbsError: 1.30905e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.92640e-16	AbsError: 1.30905e+02
#       Equation: "HoleContinuityEquation"	RelError: 3.44774e-13	AbsError: 3.86384e-10
#       Equation: "PotentialEquation"	RelError: 7.51072e-17	AbsError: 3.23820e-17
#     Region: "zone_4"	RelError: 6.27909e-15	AbsError: 1.30125e+02
#       Equation: "ElectronContinuityEquation"	RelError: 6.03189e-15	AbsError: 4.33094e-12
#       Equation: "HoleContinuityEquation"	RelError: 1.77343e-16	AbsError: 1.30125e+02
#       Equation: "PotentialEquation"	RelError: 6.98533e-17	AbsError: 3.11296e-17
#     Region: "zone_5"	RelError: 2.59699e-15	AbsError: 1.33076e+02
#       Equation: "ElectronContinuityEquation"	RelError: 2.43097e-15	AbsError: 3.39068e-13
#       Equation: "HoleContinuityEquation"	RelError: 1.06063e-16	AbsError: 1.33076e+02
#       Equation: "PotentialEquation"	RelError: 5.99609e-17	AbsError: 2.87753e-17
#     Region: "zone_6"	RelError: 1.81316e-13	AbsError: 1.50125e+02
#       Equation: "ElectronContinuityEquation"	RelError: 1.00150e-16	AbsError: 1.50125e+02
#       Equation: "HoleContinuityEquation"	RelError: 1.81152e-13	AbsError: 2.70241e-11
#       Equation: "PotentialEquation"	RelError: 6.42551e-17	AbsError: 2.92746e-17
# DEVSIM output has been saved!
# DEVSIM output has been saved!
# [24-10-17 17:27:44.597][SUPPORT]: Running postProcessHeatSimulation : /home/marc/Documents/src/tidy3d-core/_build_release/bin/flow360runner.py /home/marc/Documents/src/tidy3d-core/_build_release/bin/postprocess_heat_simulation.py --sim_file ./tmp/heat_simulation.pckl --sim_data_file ./output/simulation_data.hdf5 --heat_charge_config {'cases': './current_sim.pckl', 'heat_sim_config': './HEAT_case_config.json', 'heat_mesh_casefile': './HEAT_mesh_config.json', 'heat_vtu_file': './HEAT_proc0.vtu', 'conduction_sim_config': './CONDUCTION_case_config.json', 'conduction_mesh_casefile': './CONDUCTION_mesh_config.json', 'conduction_vtu_file': './CONDUCTION_proc0.vtu', 'heat_time_series_base': './volume_time_', 'devsim_config': './DEVSIM_config.json', 'devsim_vtu_file': 'devsim_3D.vtu', 'devsim_bias_series_base': 'devsim_bias_', 'devsim_IV_file': 'devsim_IV.pckl', 'doping_SpatialDataArray': 'doping_SpatialDataArrays.pckl'}
# [24-10-17 17:27:44.598][SUPPORT]: **********   Begin content of postProcessHeatSimulation.log **********
# [24-10-17 17:28:12.717][SUPPORT]: **********   End content of postProcessHeatSimulation.log **********
# [24-10-17 17:28:12.718][SUPPORT]: Finishing postProcessHeatSimulation: execution time is 28.12 seconds
# [24-10-17 17:28:12.718][SUPPORT]: Compressing ./output/simulation_data.hdf5.
# [24-10-17 17:28:12.718][SUPPORT]: Pigz binary is not found. Using gzip.
# [24-10-17 17:28:17.260][SUPPORT]: Running uploadFiles : /bin/true
# [24-10-17 17:28:17.261][SUPPORT]: **********   Begin content of uploadFiles.log **********
# [24-10-17 17:28:17.261][SUPPORT]: **********   End content of uploadFiles.log **********
# [24-10-17 17:28:17.261][SUPPORT]: Finishing uploadFiles: execution time is 0.00 seconds
# [24-10-17 17:28:17.261][SUPPORT]: **********   Begin content of downloadAuxFiles.log **********
# [24-10-17 17:28:17.261][SUPPORT]: **********   End content of downloadAuxFiles.log **********
# [24-10-17 17:28:17.261][SUPPORT]: Finishing downloadAuxFiles: execution time is 432.07 seconds
# [24-10-17 17:28:17.261][SUPPORT]: Running taskFinishUpdate : /bin/true status totalSolverTime : success 427528
# [24-10-17 17:28:17.262][SUPPORT]: **********   Begin content of taskFinishUpdate.log **********
# [24-10-17 17:28:17.262][SUPPORT]: **********   End content of taskFinishUpdate.log **********
# [24-10-17 17:28:17.262][SUPPORT]: Finishing taskFinishUpdate: execution time is 0.00 seconds
# [24-10-17 17:28:17.262][SUPPORT]: Found decompressed simulation data file.
# [24-10-17 17:28:17.262][SUPPORT]: Running postVizDenormalize : /home/marc/Documents/src/tidy3d-core/_build_release/bin/flow360runner.py /home/marc/Documents/src/tidy3d-core/_build_release/bin/denormalize.py --sim_data ./output/simulation_data.hdf5 --save_dir ./output/ --num_proc 1
# [24-10-17 17:28:17.263][SUPPORT]: **********   Begin content of postVizDenormalize.log **********
# 17:28:18 CEST ERROR: Unknown simulation data type.
# [24-10-17 17:28:18.483][SUPPORT]: **********   End content of postVizDenormalize.log **********
# [24-10-17 17:28:18.483][SUPPORT]: Finishing postVizDenormalize: execution time is 1.22 seconds
# [24-10-17 17:28:18.483][DEBUG  ]: runCommand for postVizDenormalize failed
# [24-10-17 17:28:18.483][SUPPORT]: runCommand for postVizDenormalize failed
# [24-10-17 17:28:18.483][SUPPORT]: Running UpdateClient2 : /bin/true denormalizeStatus : error
# [24-10-17 17:28:18.484][SUPPORT]: **********   Begin content of UpdateClient2.log **********
# [24-10-17 17:28:18.484][SUPPORT]: **********   End content of UpdateClient2.log **********
# [24-10-17 17:28:18.484][SUPPORT]: Finishing UpdateClient2: execution time is 0.00 seconds
# [24-10-17 17:28:18.486][SUPPORT]: Processing Tidy3D Heat Solver, pipeline tidy3dHeatSolverPipeline complete.
# Traceback (most recent call last):
#   File "/home/marc/Documents/src/tidy3d-core/_build_release/bin/denormalize.py", line 32, in <module>
#     denormalize(simfile, save_dir)
#   File "/home/marc/Documents/tidy3D_python/tidy3d_local/lib/python3.12/site-packages/tidy3d_denormalizer/denormalizer.py", line 207, in denormalize
#     denormalize_directly(sim_data=sim_data, base_dir=base_dir)
#                                   ^^^^^^^^
# UnboundLocalError: cannot access local variable 'sim_data' where it is not associated with a value
# Traceback (most recent call last):
#   File "/home/marc/Documents/src/tidy3d-core/_build_release/bin/flow360runner.py", line 36, in <module>
#     subprocess.check_call([sys.executable, '-u'] + args)
#   File "/usr/lib/python3.12/subprocess.py", line 413, in check_call
#     raise CalledProcessError(retcode, cmd)
# subprocess.CalledProcessError: Command '['/home/marc/Documents/tidy3D_python/tidy3d_local/bin/python3', '-u', '/home/marc/Documents/src/tidy3d-core/_build_release/bin/denormalize.py', '--sim_data', './output/simulation_data.hdf5', '--save_dir', './output/', '--num_proc', '1']' returned non-zero exit status 1.
# 17:28:19 CEST WARNING: Structure 'oxide' listed as a non-refined structure in
#               'HeatChargeSimulation.grid_spec' is not present in
#               'HeatChargeSimulation.structures'
#               WARNING: Could not execute validator 'warn_no_data' because field
#               'monitor' failed validation.
#               WARNING: Could not execute validator 'warn_no_data' because field
#               'monitor' failed validation.

# %% [markdown]
# ### Post-process data

# %%
#devsim_data[volt_y0_mnt.name].voltage.sel(z=0).plot(grid=False)
print(devsim_data[charge_monitor_z0.name].data_series.parameter_array)

indices = [0]
indices.append(int(np.ceil(devsim_data[charge_monitor_z0.name].data_series.num_fields_saved/2)))
indices.append(int(np.ceil(devsim_data[charge_monitor_z0.name].data_series.num_fields_saved-1)))

series = devsim_data[charge_monitor_z0.name].data_series
sets_to_plot = [[], []]
if devsim_data[charge_monitor_z0.name].data_series.num_fields_saved > 2:
    fig, ax = plt.subplots(2, 3)
    for n, index in enumerate(indices):
        sets_to_plot[0].append(
            devsim_data[charge_monitor_z0.name].data_series.get_field("Potential", index)
        )
        sets_to_plot[0][n].plot(ax=ax[0][n], grid=False)
        ax[0][n].set_xlim((-0.3, 0.3))
        sets_to_plot[1].append(
            np.log(devsim_data[charge_monitor_z0.name].data_series.get_field("Electrons", index))
        )
        sets_to_plot[1][n].plot(ax=ax[1][n], grid=False)
        ax[1][n].set_title("Bias {0:0.2f}V".format(series.parameter_array[index]))
        ax[1][n].set_xlim((-0.3, 0.3))

plt.tight_layout()
# Out:
# (-0.5, -0.26315789473684215, -0.026315789473684237, 0.21052631578947367, 0.4473684210526315, 0.6842105263157894, 0.9210526315789473, 1.157894736842105, 1.394736842105263, 1.6315789473684208, 1.8684210526315788, 2.1052631578947367, 2.3421052631578947, 2.5789473684210527, 2.81578947368421, 3.052631578947368, 3.289473684210526, 3.526315789473684, 3.7631578947368416, 4.0)

# %%
# capacitance from device
ce = np.array(devsim_data.device_characteristics["cv_curve_e"].data)
ch = np.array(devsim_data.device_characteristics["cv_curve_h"].data)
v = devsim_data.device_characteristics["cv_curve_e"].coords["Voltage (V)"].data

mnt_3D_ce = np.array(devsim_data[charge_3D_mnt.name].capacitance_curve["cv_curve_e"].data)
mnt_3D_ch = np.array(devsim_data[charge_3D_mnt.name].capacitance_curve["cv_curve_h"].data)
v_3D_mnt = np.array(devsim_data[charge_3D_mnt.name].capacitance_curve["cv_curve_h"].coords["Voltage (V)"].data)
# paper data
c_paper = [2.6, 2.21, 1.95,  1.8,  1.65, 1.55,  1.5]
v_paper = [-0.4, 0.0,  0.5,  1.0,  2.0,  3.0,   4]

c_wg_lumerical = np.array([0.215, 0.18, 0.155, 0.14, 0.12, 0.105, 0.095])
c_wg_lumerical_inAir = np.array([0.19, 0.155, 0.135, 0.12, 0.105, 0.091, 0.082])

#plt.plot(v, -0.5*(ce+ch)/z_size * 1e-3, "k.-", label="devsim - wg only" )
plt.plot(v_3D_mnt, -0.5*(mnt_3D_ce+mnt_3D_ch)/z_size * 10, "k.-", label="devsim - wg only" )
#plt.plot(v_paper, c_paper, "r-", label="Measurement")
plt.plot(v_paper, c_wg_lumerical*10, "r-", label="Lumerical - wg only")
#plt.plot(v_paper, c_wg_lumerical_inAir*10, "r-", label="Lumerical - wg only")
plt.xlabel("Reverse bias (V)")
plt.ylabel("pF/cm")
#plt.ylim([1.2, 2.8])
plt.legend()
plt.grid()
plt.show()

# %%
# capacitance from monitor - waveguide area

c_lumerical_wg_in_air = np.array([0.095, 0.155, 0.14, 0.12, 0.11, 0.1, 0.0925, 0.084])
b_lumerical_wg_in_air = np.array([-0.4, 0,     0.4,  1.1,  1.65, 2.3, 3,     4])

c_lumerical_wg_in_SiO2 = np.array([0.181, 0.16, 0.145, 0.13, 0.12, 0.11, 0.1])
b_lumerical_wg_in_SiO2 = np.array([0,     0.5,   1,    1.7,  2.3,  3,     4])

c_lumerical_wg_deg_in_Air = np.array([0.19, 0.1551, 0.1357, 0.12, 0.11, 0.1, 0.09, 0.085])
b_lumerical_wg_deg_in_Air = np.array([-0.4, 0,     0.5,     1.15,  1.7,  2.4, 3.3,  4])

mnt_v = np.array(devsim_data[charge_monitor_z0.name].capacitance_curve["cv_curve_e"].coords["Voltage (V)"].data)
mnt_ce = np.array(devsim_data[charge_monitor_z0.name].capacitance_curve["cv_curve_e"].data)
mnt_ch = np.array(devsim_data[charge_monitor_z0.name].capacitance_curve["cv_curve_h"].data)

plt.plot(mnt_v, -0.5*(mnt_ce+mnt_ch) * 10, 'k.-', label="devsim - wg -2D mnt")
plt.plot(mnt_v, -0.5*(mnt_3D_ce+mnt_3D_ch) * 10/ z_size, 'b.-', label="devsim - wg -3D mnt")
#plt.plot(b_lumerical_wg_in_air, c_lumerical_wg_in_air*10, 'r-', label="Lumerical - wg")
#plt.plot(b_lumerical_wg_in_SiO2, c_lumerical_wg_in_SiO2*10, 'r-', label="Lumerical - wg")
plt.plot(b_lumerical_wg_deg_in_Air, c_lumerical_wg_deg_in_Air*10, 'r-', label="Lumerical - wg")
plt.xlabel("Reverse bias (V)")
plt.ylabel("pF/cm")
plt.legend()
plt.grid()
#devsim_data[charge_monitor_z0.name].capacitance_curve["cv_curve_e"].plot()
